# %% [markdown]
# # vMF-VAE modelling for new MCMCP (study2)
#
# ## What is von Mises-Fisher distribution?
# > vMF is a kind of distribution over a (d-1)-dimentional hypersphere within a d-dimensional space, which could be a uniform distribution over the sphere, or a peak centered at any given vector \mu (with a parameter kappa controlling the variance).
#
# ## Why I plan to replace the gaussian prior with von Mises-Fisher distribution?
# * Origin gravity: Gaussian prior will push data towards the origin no matter what category it is;
# > First, it makes no sense to encourage all categories to cluster in the center; then, this effect will cause imbalance distributions of different clusters, hindering the diversity of generation.
# * Hard to use uniform distribution in a hyper-plane space;
# * vMF provide a grace solution to uniform facial affects, which could improve the representative ability of latent space;
# * Emotions' distribution is theoretically 2-d with a potential Circumplex structure (Russell, 1980), lines up well with the vMF hypersphere;
# * Put affect on 2-d manifold rather than 3-d space could ease both sampling process and space mapping.

# %%
import os
import gc
import numpy as np
import torch
from torchsummary import summary
from torch.cuda.amp import GradScaler, autocast
from train import train
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from math import pi

from dataset import get_dataloaders
import models
from utils import setup_seed, latent_space, manifold, reconstruction

# %%
class config:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    latent_dim = 3  # determine shape of latent space
    distribution = 'vmf'
    kappa = 35

    data_path = "./data/cafe/balance_all"
    image_size = (64, 40)  # determine model layer size and data preprocessing: (40, 40) or (64, 40)
    label_list = {'0':'Neutral', '1':'Happy', '2':'Sad', '3':'Angry', '4':'Disgusted', '5':'Fear', '6':'Surprise'}

    weight_class = 1
    batchsize = 64
    n_epoch = 50
    learning_rate = 1e-3
    scheduler = None
    saved_path = "./saved_models/"
    
print(config.device)
# Out:
# cuda

# %%
# data
train_loader = get_dataloaders(path=config.data_path, bs=config.batchsize, input_size=config.image_size)
# show a case
for i, (images, labels) in enumerate(train_loader):
    if i==0:
        print('max value in image tensor is:', torch.max(images[0, 0, :, :]))
        print('size:', images[0, 0, :, :].size())
        plt.imshow(images[0, 0, :, :])
        print(labels[0])
# Out:
# max value in image tensor is: tensor(0.9686)
# size: torch.Size([64, 40])
# tensor(6)

# %%
# model
s_vae = models.VAE(z_dim=config.latent_dim, 
                   size=config.image_size, 
                   distribution=config.distribution, 
                   kappa=config.kappa, 
                   device=config.device).to(config.device)  
# default as vmf-VAE
summary(s_vae, (1,)+config.image_size)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 32, 20]             416
#             Conv2d-2           [-1, 32, 16, 10]          12,832
#             Conv2d-3           [-1, 32, 16, 10]          25,632
#            Dropout-4                 [-1, 5120]               0
#             Linear-5                  [-1, 128]         655,488
#            Dropout-6                  [-1, 128]               0
#             Linear-7                    [-1, 3]             387
#             Linear-8                    [-1, 1]             129
#             Linear-9                  [-1, 128]             512
#           Dropout-10                  [-1, 128]               0
#            Linear-11                 [-1, 5120]         660,480
#           Dropout-12                 [-1, 5120]               0
#   ConvTranspose2d-13           [-1, 16, 32, 20]          12,816
#   ConvTranspose2d-14            [-1, 1, 64, 40]             401
#            Linear-15                    [-1, 7]              28
#           Softmax-16                    [-1, 7]               0
# ================================================================
# Total params: 1,369,121
# Trainable params: 1,369,121
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 0.38
# Params size (MB): 5.22
# Estimated Total Size (MB): 5.61
# ----------------------------------------------------------------

# %% [markdown]
# ### training

# %%
# optimizer
optimizer = torch.optim.Adam(s_vae.parameters(), lr=config.learning_rate)
# amp: automatic mixed precision training 
scaler = GradScaler()  
# scheduler to adjust the learning rate
if config.scheduler == 'reduce':
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.75, patience=5, verbose=False)

# training
# setup_seed(0)
for epoch in range(config.n_epoch):
    rec_loss, kl_loss, cla_loss = train(s_vae, train_loader, optimizer, config.device, scaler, w_cla=config.weight_class)
    
    if config.scheduler == 'reduce':
        scheduler.step(rec_loss + kl_loss + cla_loss)

    print("Epoch%3d/%3d:" % (epoch+1, config.n_epoch))
    print("RC_loss mean for the epoch is %8.3f" % (rec_loss))
    print("KL_loss mean for the epoch is %8.3f" % (kl_loss))
    print("CL_loss mean for the epoch is %8.3f" % (cla_loss))
    print("=====XXX=====")

# finish the train
model_name = "k35_e50.pt"
torch.save(s_vae, config.saved_path + model_name)
print("model has been saved as:", config.saved_path + model_name)

# %% [markdown]
# ### vasualization

# %%
model_name = "k35_e50.pt"  # "k30_e50, "
model = torch.load(config.saved_path + model_name)

# %%
# %matplotlib widget 
latent_space(model, train_loader, latent_dims=config.latent_dim, label_list=config.label_list, device=config.device, legend=True, sample="mean")
# Out:
# Number of data points: 955
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %%
xy_resolution = 7
manifold(model, theta=list(b*pi for b in np.linspace(0, 2, xy_resolution)), 
         resolution=12, 
         device=config.device)  # theta belons to the range 0-2pi
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
reconstruction(model, train_loader, n_show=10, device=config.device)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
len(train_loader)
# Out:
# 15

# %%
np.sum(sample_w3((100,), 15).numpy().squeeze() > 0.9)
# Out:
# 81

# %%
np.sum(sample_from_pw(100, 1, 3) > 0.5)
# Out:
# 50

# %%
(torch.tensor([1, 2, 3]) * 0) + 4
# Out:
# tensor([4, 4, 4])

# %%
from math import pi
np.cos(pi)
# Out:
# -1.0
