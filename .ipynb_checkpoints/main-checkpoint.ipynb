# %% [markdown]
# # vMF-VAE modelling for new MCMCP (study2)
#
# ## What is von Mises-Fisher distribution?
# > vMF is a kind of distribution over a (d-1)-dimentional hypersphere within a d-dimensional space, which could be a uniform distribution over the sphere, or a peak centered at any given vector \mu (with a parameter kappa controlling the variance).
#
# ## Why I plan to replace the gaussian prior with von Mises-Fisher distribution?
# * Origin gravity: Gaussian prior will push data towards the origin no matter what category it is;
# > First, it makes no sense to encourage all categories to cluster in the center; then, this effect will cause imbalance distributions of different clusters, hindering the diversity of generation.
# * Hard to use uniform distribution in a hyper-plane space;
# * vMF provide a grace solution to uniform facial affects, which could improve the representative ability of latent space;
# * Emotions' distribution is theoretically 2-d with a potential Circumplex structure (Russell, 1980), lines up well with the vMF hypersphere;
# * Put affect on 2-d manifold rather than 3-d space could ease both sampling process and space mapping.
#
# ## Why use 3-d latent space?
# * I think we should stay with 3-d space (with 2-d sphere in it) because we need enough space to accomodate neutral and other faces, and also we can just estimate the density over the surface of hypersphere instead of the whole space where hypersphere is embedded in.
#
# ## What do the hyper-parameters mean and why to select specific values, like kappa particularly?
# * The main concern in this model's training is to find a suitable kappa for 3-d vmf distribution which is big enough (the distribution become slimmer) for generator to learn face details (e.g., kappa=1 produces a generator that is able to generate an average face merely over the latent space, with a negative diversity, and hard to be seperated into different clusters as well --- high stickiness among the data), but also not too big to avoid reconstruting the facial identity information, making the model concentrate on the facial affect, and be continuous as well.
# * Based on the current trials, k=300 with no matter how many epoches has the best performance.
#
# ## How much epochs do we need?
# * Monitor the tendency of clustering in training, to determine when to terminate the training and guarantee the sparse distribution of the data.
# * $collapse = \frac{\sum^{n-1}_{i=1}{\sum^{n}_{j=i}{distance(cluster_i, cluster_j)}}}{Within Cluster Distance}$
# * collapse within [4, 5] is a good threshold to terminate the training;
# * To guarantee the performance of decoder, after training I freeze the encoder and classifier and finetune the decoder for 20 epoches with 0.0001 learning rate;
#
# ## The vmf-VAE provides us a pure, continuous, finite facial-expression latent space, with good fidelity and diversity!
# ## The final question is, how to evaluate the model (not important but necessary) --- FID

# %%
import os
import gc
import numpy as np
import torch
from torchsummary import summary
from torch.cuda.amp import GradScaler, autocast
from train import train
from transfer import transfer
from finetune import finetune
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from math import pi

from dataset import get_cafeloaders
from dataset_jaffe import get_jaffeloaders
from dataset_fer2013 import get_dataloaders
import models
from utils import accuracy, accuracy_res, setup_seed, latent_space, manifold_sphere, reconstruction, latent_sample

# %%
class config:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    # distribution_id = 'normal' # or normal
    distribution_emo = 'vmf' # or normal
    # latent_dim_id = 2  # determine shape of latent space, 2 or 3
    latent_dim_emo = 3  # determine shape of latent space, 2 or 3
    radius = 1.0  #controlling the radius of the hypersphere
    kappa = 500  # enough details but not too much, set as 500 according to the area of recontructive sampling

    data_path = "./data/cafe/balance_all"  # "./data/jaffe"
    image_size = (64, 40)  # determine the raw size before transform: (40, 40) or (64, 40) or (48, 40)
    label_list = {'0':'Neutral', '1':'Happy', '2':'Sad', '3':'Angry', '4':'Disgusted', '5':'Fear', '6':'Surprise'}

    alpha = 3e-1
    weight_recon =  0 #  1 - alpha
    # weight_class_id = 0  # weight of classfier loss
    weight_class_emo = 1
    
    aug = False
    Ncrop = False 
    if Ncrop:
        batchsize = 16  # with Ncrop = 5
    elif not Ncrop:
        batchsize = 64
    else:
        raise NotImplemented
    
    loss = torch.nn.MSELoss  
    # "MSELoss" or "BCEWithLogitsLoss", when use BCEWithLogitsLoss, sigmoid af in the end of decoder should be removed!!
    n_epoch = 200
    transfer_epoch = 100
    learning_rate = 1e-3
    scheduler = None  # learning rate schedule, "reduce", None ...
    saved_path = "./saved_models/"

    # regularization = False  # deperacated
    # weight_regularization = 0
    
print(config.device)

# %%
# data
# Kfold = "3/5"
# valid_loader = get_jaffeloaders(path=config.train_path, 
#                                bs=config.batchsize, 
#                                augment=config.aug, input_size=config.image_size)
train_loader = get_cafeloaders(path=config.data_path, 
                               bs=config.batchsize, 
                               augment=config.aug, input_size=config.image_size, 
                               k_fold=None)
transfer_loader, _, _ = get_dataloaders(bs=128)

# %%
resnet18 = models.ResNet18()
# print(resnet18)
checkpoint = torch.load("models/best_checkpoint.tar")  # best_checkpoint.tar
# model.load_state_dict(checkpoint['params'])
resnet18.load_state_dict(checkpoint['model_state_dict'])
resnet18 = resnet18.to(config.device)

# %%
# show a case when augment is on
for i, data in enumerate(valid_loader):
    if i==0 and config.aug and config.Ncrop:
        print('max value in image tensor is:', torch.max(data[0][0, 0, :, :]))
        print('size:', data[1].size())
        
        f, a = plt.subplots(1, 6)
        plt.setp(a.flat, xticks=[], yticks=[])
        a[0].imshow(data[0].cpu().numpy()[0, 0, :, :])
        for i in range(1, 6):
            a[i].imshow(data[1].cpu().numpy()[0, i-1, 0, :, :])
            
        print(data[2][0])

    elif i==0 and config.aug and config.Ncrop==False:
        print('max value in image tensor is:', torch.max(data[0][0, 0, :, :]))
        print('size:', data[1].size())
        
        f, a = plt.subplots(1, 2)
        plt.setp(a.flat, xticks=[], yticks=[])
        a[0].imshow(data[0].cpu().numpy()[0, 0, :, :])
        a[1].imshow(data[1].cpu().numpy()[0, 0, :, :])
            
        print(data[2][0])
        
    elif i==0 and config.aug==False and config.Ncrop==False:
        print('max value in image tensor is:', torch.max(data[0][0, 0, :, :]))
        print('size:', data[0].size())
        plt.imshow(data[0].cpu().numpy()[0, 0, :, :])
        print(data[1][0])
# Out:
# max value in image tensor is: tensor(0.0034)
# size: torch.Size([64, 1, 40, 40])
# tensor([[[0.0013, 0.0012, 0.0012,  ..., 0.0012, 0.0011, 0.0012],
#          [0.0012, 0.0013, 0.0013,  ..., 0.0012, 0.0012, 0.0011],
#          [0.0012, 0.0012, 0.0012,  ..., 0.0013, 0.0012, 0.0011],
#          ...,
#          [0.0018, 0.0021, 0.0021,  ..., 0.0014, 0.0022, 0.0029],
#          [0.0020, 0.0020, 0.0021,  ..., 0.0012, 0.0018, 0.0026],
#          [0.0020, 0.0020, 0.0021,  ..., 0.0012, 0.0017, 0.0023]]])

# %% [markdown]
# ### finetune the resnet

# %%
for p in resnet18.parameters():
    p.requires_grad = True
# for i,p in enumerate(model.parameters()):
#     if i < 60:
#         p.requires_grad = False
# for name, param in model.named_parameters():
#     if param.requires_grad:
#         print(name)

# %%
# optimizer
optimizer = torch.optim.Adam([p for p in resnet18.parameters() if p.requires_grad == True], lr=1e-6, betas=(0.9, 0.99))
# amp: automatic mixed precision training 
scaler = GradScaler()  
# setup_seed(0)
for epoch in range(config.finetune_epoch):
    cla_loss = finetune(resnet18, train_loader, optimizer, scaler, config) 
        
    accuracy_valid = accuracy_res(resnet18, train_loader, config)

    print("Epoch%3d/%3d: CL_loss_emo%8.3f, accuracy_train%8.3f" 
          % (epoch+1, config.finetune_epoch, cla_loss, accuracy_valid))
    
    if accuracy_valid > 0.7: 
        break
# Out:
# Epoch  1/100: CL_loss_emo1517.935, accuracy_train   0.512
# Epoch  2/100: CL_loss_emo1467.793, accuracy_train   0.539
# Epoch  3/100: CL_loss_emo1390.086, accuracy_train   0.565
# Epoch  4/100: CL_loss_emo1314.504, accuracy_train   0.589
# Epoch  5/100: CL_loss_emo1242.270, accuracy_train   0.604
# Epoch  6/100: CL_loss_emo1183.253, accuracy_train   0.622
# Epoch  7/100: CL_loss_emo1118.407, accuracy_train   0.639
# Epoch  8/100: CL_loss_emo1061.006, accuracy_train   0.661
# Epoch  9/100: CL_loss_emo1002.500, accuracy_train   0.678
# Epoch 10/100: CL_loss_emo 944.661, accuracy_train   0.696
# Epoch 11/100: CL_loss_emo 895.553, accuracy_train   0.721

# %% [markdown]
# ### combine the resnet

# %%
for p in resnet18.parameters():
    p.requires_grad = False
for name, param in resnet18.named_parameters():
    if param.requires_grad:
        print(name)

# %%
vae = models.VAE(z_dim=config.latent_dim_emo,
                 size=config.image_size,
                 distribution=config.distribution_emo,
                 kappa=config.kappa, 
                 radius=config.radius, 
                 device=config.device).to(config.device)

# %%
class resVAE(torch.nn.Module):
    def __init__(self, submodel1, submodel2):
        super(resVAE, self).__init__()
        self.submodel1 = submodel1
        self.submodel2 = submodel2
 
    def forward(self, x):
        _, x = self.submodel1(x)
        (z_mean, z_var), (q_z, p_z), z, (x_rec, x_cla) = self.submodel2(x)
        
        return (z_mean, z_var), (q_z, p_z), z, (x_rec, x_cla)

# %%
resnetVAE = resVAE(resnet18, vae)

# %%
for name, param in resnetVAE.named_parameters():
    print(name)
# Out:
# submodel1.conv1.weight
# submodel1.bn1.weight
# submodel1.bn1.bias
# submodel1.layer1.0.conv1.weight
# submodel1.layer1.0.bn1.weight
# submodel1.layer1.0.bn1.bias
# submodel1.layer1.0.conv2.weight
# submodel1.layer1.0.bn2.weight
# submodel1.layer1.0.bn2.bias
# submodel1.layer1.1.conv1.weight
# submodel1.layer1.1.bn1.weight
# submodel1.layer1.1.bn1.bias
# submodel1.layer1.1.conv2.weight
# submodel1.layer1.1.bn2.weight
# submodel1.layer1.1.bn2.bias
# submodel1.layer2.0.conv1.weight
# submodel1.layer2.0.bn1.weight
# submodel1.layer2.0.bn1.bias
# submodel1.layer2.0.conv2.weight
# submodel1.layer2.0.bn2.weight
# submodel1.layer2.0.bn2.bias
# submodel1.layer2.0.shortcut.0.weight
# submodel1.layer2.0.shortcut.1.weight
# submodel1.layer2.0.shortcut.1.bias
# submodel1.layer2.1.conv1.weight
# submodel1.layer2.1.bn1.weight
# submodel1.layer2.1.bn1.bias
# submodel1.layer2.1.conv2.weight
# submodel1.layer2.1.bn2.weight
# submodel1.layer2.1.bn2.bias
# submodel1.layer3.0.conv1.weight
# submodel1.layer3.0.bn1.weight
# submodel1.layer3.0.bn1.bias
# submodel1.layer3.0.conv2.weight
# submodel1.layer3.0.bn2.weight
# submodel1.layer3.0.bn2.bias
# submodel1.layer3.0.shortcut.0.weight
# submodel1.layer3.0.shortcut.1.weight
# submodel1.layer3.0.shortcut.1.bias
# submodel1.layer3.1.conv1.weight
# submodel1.layer3.1.bn1.weight
# submodel1.layer3.1.bn1.bias
# submodel1.layer3.1.conv2.weight
# submodel1.layer3.1.bn2.weight
# submodel1.layer3.1.bn2.bias
# submodel1.layer4.0.conv1.weight
# submodel1.layer4.0.bn1.weight
# submodel1.layer4.0.bn1.bias
# submodel1.layer4.0.conv2.weight
# submodel1.layer4.0.bn2.weight
# submodel1.layer4.0.bn2.bias
# submodel1.layer4.0.shortcut.0.weight
# submodel1.layer4.0.shortcut.1.weight
# submodel1.layer4.0.shortcut.1.bias
# submodel1.layer4.1.conv1.weight
# submodel1.layer4.1.bn1.weight
# submodel1.layer4.1.bn1.bias
# submodel1.layer4.1.conv2.weight
# submodel1.layer4.1.bn2.weight
# submodel1.layer4.1.bn2.bias
# submodel1.linear.weight
# submodel1.linear.bias
# submodel2.fc_mean.weight
# submodel2.fc_mean.bias
# submodel2.fc_var.weight
# submodel2.fc_var.bias
# submodel2.fc_de0.weight
# submodel2.fc_de0.bias
# submodel2.fc_de1.weight
# submodel2.fc_de1.bias
# submodel2.Tcov_de2.weight
# submodel2.Tcov_de2.bias
# submodel2.Tcov_de3.weight
# submodel2.Tcov_de3.bias
# submodel2.Tcov_de4.weight
# submodel2.Tcov_de4.bias
# submodel2.linear.weight
# submodel2.linear.bias

# %%
for i,p in enumerate(resnetVAE.parameters()):
    if i < 62:
        p.requires_grad = False
for name, param in resnetVAE.named_parameters():
    if param.requires_grad:
        print(name)
# Out:
# submodel2.fc_mean.weight
# submodel2.fc_mean.bias
# submodel2.fc_var.weight
# submodel2.fc_var.bias
# submodel2.fc_de0.weight
# submodel2.fc_de0.bias
# submodel2.fc_de1.weight
# submodel2.fc_de1.bias
# submodel2.Tcov_de2.weight
# submodel2.Tcov_de2.bias
# submodel2.Tcov_de3.weight
# submodel2.Tcov_de3.bias
# submodel2.Tcov_de4.weight
# submodel2.Tcov_de4.bias
# submodel2.linear.weight
# submodel2.linear.bias

# %% [markdown]
# ### transfer

# %%
# optimizer
optimizer = torch.optim.Adam([p for p in resnetVAE.parameters() if p.requires_grad == True], lr=config.learning_rate, betas=(0.9, 0.99))
# amp: automatic mixed precision training 
scaler = GradScaler()  
# setup_seed(0)
for epoch in range(config.n_epoch):
    cla_loss = transfer(resnetVAE, transfer_loader, optimizer, scaler, config) 
        
    # acc = accuracy(resnetVAE, train_loader, config)

    print("Epoch%3d/%3d: CL_loss_emo%8.3f" 
          % (epoch+1, config.n_epoch, cla_loss))
# Out:
# Epoch  1/200: CL_loss_emo255116.016
# Epoch  2/200: CL_loss_emo244077.859
# Epoch  3/200: CL_loss_emo233711.188
# Epoch  4/200: CL_loss_emo225033.141
# Epoch  5/200: CL_loss_emo218310.875
# Epoch  6/200: CL_loss_emo212203.609
# Epoch  7/200: CL_loss_emo206175.781
# Epoch  8/200: CL_loss_emo200991.344
# Epoch  9/200: CL_loss_emo196769.641
# Epoch 10/200: CL_loss_emo193359.938
# Epoch 11/200: CL_loss_emo190642.422
# Epoch 12/200: CL_loss_emo188599.156
# Epoch 13/200: CL_loss_emo186975.516
# Epoch 14/200: CL_loss_emo185750.391
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       5 # setup_seed(0)
#       6 for epoch in range(config.n_epoch):
# ----> 7     cla_loss = transfer(resnetVAE, transfer_loader, optimizer, scaler, config)
#       9     # acc = accuracy(resnetVAE, train_loader, config)
#      11     print("Epoch%3d/%3d: CL_loss_emo%8.3f"
#      12           % (epoch+1, config.n_epoch, cla_loss))
#
# File /home/transfer.py:31, in transfer(model, train_loader, optimizer, scaler, config)
#      28 base_images = base_images.view(-1, c, h, w)  # the first dimension becomes Ncrop x batch-size
#      29 labels = torch.repeat_interleave(labels, repeats=ncrops, dim=0)
# ---> 31 _, _, _, (_, labels_) = model(base_images)
#      33 loss_cla_emo = nn.CrossEntropyLoss(reduction="none")(labels_, labels).sum(-1).mean()
#      35 loss = loss_cla_emo
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[7], line 9, in resVAE.forward(self, x)
#       7 def forward(self, x):
#       8     _, x = self.submodel1(x)
# ----> 9     (z_mean, z_var), (q_z, p_z), z, (x_rec, x_cla) = self.submodel2(x)
#      11     return (z_mean, z_var), (q_z, p_z), z, (x_rec, x_cla)
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /home/models/vMF_VAE.py:117, in VAE.forward(self, x)
#     115 def forward(self, x):
#     116     z_mean, z_var = self.encoder(x)
# --> 117     q_z, p_z = self.reparameterize(z_mean, z_var, self.radius)
#     118     z = q_z.rsample()  # sampling using reparameterization trick
#     119     x_rec = self.decoder(z)
#
# File /home/models/vMF_VAE.py:108, in VAE.reparameterize(self, z_mean, z_var, radius)
#     106     p_z = torch.distributions.normal.Normal(torch.zeros_like(z_mean), torch.ones_like(z_var))
#     107 elif self.distribution == 'vmf':
# --> 108     q_z = VonMisesFisher(z_mean, z_var, k=self.kappa, radius=radius)  # new real kappa is here
#     109     p_z = HypersphericalUniform(self.z_dim - 1, radius, device=self.device)
#     110 else:
#
# File /home/hypersphere/distributions/von_mises_fisher.py:42, in VonMisesFisher.__init__(self, loc, scale, validate_args, k, radius)
#      40 self.device = loc.device
#      41 self.__m = loc.shape[-1]
# ---> 42 self.__e1 = (torch.Tensor([radius] + [0] * (loc.shape[-1] - 1))).to(self.device)
#      43 self.k = k
#      44 self.radius = radius
#
# KeyboardInterrupt:

# %% [markdown]
# ### training

# %%
# optimizer
optimizer = torch.optim.Adam([p for p in resnetVAE.parameters() if p.requires_grad == True], lr=config.learning_rate, betas=(0.9, 0.99))
# amp: automatic mixed precision training 
scaler = GradScaler()  
# scheduler to adjust the learning rate
if config.scheduler == 'reduce':
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', factor=0.75, patience=5, verbose=False)

# training process trend monitor
# loss_reconstruction = []
# loss_classification = []
# collapse = []
accuracy_list = []

# setup_seed(0)
for epoch in range(config.n_epoch):
    rec_loss, kl_loss, cla_loss = train(resnetVAE, train_loader, optimizer, scaler, config) 
    
    if config.scheduler == 'reduce':
        scheduler.step(rec_loss + cla_loss/250)
        
    acc = accuracy(resnetVAE, train_loader, config)
    accuracy_list.append(acc)

    print("Epoch%3d/%3d: RC_loss%8.3f, KL_loss%8.3f, CL_loss_emo%8.3f, accuracy%8.3f" 
          % (epoch+1, config.n_epoch, rec_loss, kl_loss, cla_loss, acc))
    # print("=====XXX=====")

    # finish the train
#     if acc > 0.7:
#         model_name = f"test_{epoch+1}.pt"
#         torch.save(resnetVAE, config.saved_path + model_name)
#         print("model has been saved as:", config.saved_path + model_name)
#         break


# training process trend monitor
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(accuracy_list, color='tab:blue', label="acc in training")
# ax.vlines(len(loss_reconstruction)-config.finetune_epoch-1, 0, 10, linestyles='dashed', colors='yellow', label="start the decoder-finetune")
plt.grid()
plt.legend()
plt.show()
# Out:
# Epoch  1/200: RC_loss  11.484, KL_loss  88.617, CL_loss_emo1375.287, accuracy   0.810
# Epoch  2/200: RC_loss  10.030, KL_loss  88.617, CL_loss_emo1376.449, accuracy   0.812
# Epoch  3/200: RC_loss   8.090, KL_loss  88.617, CL_loss_emo1375.908, accuracy   0.811
# Epoch  4/200: RC_loss   6.868, KL_loss  88.617, CL_loss_emo1376.341, accuracy   0.812
# Epoch  5/200: RC_loss   6.189, KL_loss  88.617, CL_loss_emo1377.195, accuracy   0.812
# Epoch  6/200: RC_loss   5.825, KL_loss  88.617, CL_loss_emo1377.907, accuracy   0.811
# Epoch  7/200: RC_loss   5.576, KL_loss  88.617, CL_loss_emo1378.292, accuracy   0.810
# Epoch  8/200: RC_loss   5.407, KL_loss  88.617, CL_loss_emo1376.966, accuracy   0.810
# Epoch  9/200: RC_loss   5.287, KL_loss  88.617, CL_loss_emo1376.396, accuracy   0.816
# Epoch 10/200: RC_loss   5.204, KL_loss  88.617, CL_loss_emo1374.980, accuracy   0.808
# Epoch 11/200: RC_loss   5.146, KL_loss  88.617, CL_loss_emo1376.286, accuracy   0.809
# Epoch 12/200: RC_loss   5.108, KL_loss  88.617, CL_loss_emo1373.987, accuracy   0.812
# Epoch 13/200: RC_loss   5.086, KL_loss  88.617, CL_loss_emo1377.239, accuracy   0.812
# Epoch 14/200: RC_loss   5.062, KL_loss  88.617, CL_loss_emo1379.369, accuracy   0.811
# Epoch 15/200: RC_loss   5.049, KL_loss  88.617, CL_loss_emo1376.332, accuracy   0.811
# Epoch 16/200: RC_loss   5.039, KL_loss  88.617, CL_loss_emo1383.614, accuracy   0.812
# Epoch 17/200: RC_loss   5.029, KL_loss  88.617, CL_loss_emo1376.396, accuracy   0.809
# Epoch193/200: RC_loss   4.815, KL_loss  88.617, CL_loss_emo1376.360, accuracy   0.810
# Epoch194/200: RC_loss   4.823, KL_loss  88.617, CL_loss_emo1376.422, accuracy   0.811
# Epoch195/200: RC_loss   4.813, KL_loss  88.617, CL_loss_emo1373.574, accuracy   0.811
# Epoch196/200: RC_loss   4.831, KL_loss  88.617, CL_loss_emo1379.438, accuracy   0.809
# Epoch197/200: RC_loss   4.820, KL_loss  88.617, CL_loss_emo1381.016, accuracy   0.814
# Epoch198/200: RC_loss   4.818, KL_loss  88.617, CL_loss_emo1378.375, accuracy   0.812
# Epoch199/200: RC_loss   4.831, KL_loss  88.617, CL_loss_emo1378.545, accuracy   0.814
# Epoch200/200: RC_loss   4.828, KL_loss  88.617, CL_loss_emo1374.686, accuracy   0.810

# %%
torch.save(resnetVAE, config.saved_path + "resvae.pt")

# %% [markdown]
# ### vasualization

# %%
model_name = "test_91.pt"  # "k30_e50, k35_e50, k35_e50(2d), k35_e80(2d), k35_e80_w3(2d), k35_e80_w3(2d_40x40), k40_e80, k300_e50_v2"
model = torch.load(config.saved_path + model_name)

# %%
# %matplotlib widget 
latent_space(resnetVAE, train_loader, config, legend=True)
# Out:
# Number of data: 960
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %%
xy_resolution = 20
manifold_sphere(resnetVAE.submodel2, config, 
                theta=list(b*pi for b in np.linspace(0, 2, xy_resolution)), 
                z_resolution=20, # z_resolution works only when z_dim=3
               )  # theta belons to the range 0-2pi
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
xy_resolution = 20
conditional_manifold(model, "emo", torch.tensor([[5.6, -9.3]]), config, 
                theta=list(b*pi for b in np.linspace(0, 2, xy_resolution)), 
                z_resolution=20, # z_resolution works only when z_dim=3
               )  # theta belons to the range 0-2pi

# %%
reconstruction(resnetVAE, train_loader, n_show=10, config=config)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
len(train_loader)

# %%
latent_sample(model, config)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 latent_sample(model, config)
#
# File /home/utils.py:149, in latent_sample(model, config, n_show, std)
#     146 model.eval()
#     148 img_show = img_show.type("torch.FloatTensor").to(config.device)
# --> 149 img = model.decoder(img_show)
#     150 img = img.cpu().detach().numpy()
#     152 # plt.style.use("dark_background")
#
# File /home/models/de_vMF_VAE.py:202, in dVAE.decoder(self, z)
#     200 def decoder(self, z):
# --> 202     x = F.relu(self.fc_de0(z))
#     203     x = F.relu(self.fc_de1(x))
#     204     x = x.view(-1, 64, int(self.size[0]/8), int(self.size[1]/8))
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:114, in Linear.forward(self, input)
#     113 def forward(self, input: Tensor) -> Tensor:
# --> 114     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (10x3 and 6x128)

# %%
from hypersphere.distributions import VonMisesFisher
# %matplotlib widget

# %%
center = torch.tensor([[0, -1, 0]], dtype=torch.float64)
sampler = VonMisesFisher(center, torch.tensor([[1]], dtype=torch.float64), k=100)
samples = sampler.rsample(50)[:, 0, :]
# print(samples)
ax = plt.figure(figsize=(10, 10)).add_subplot(111, projection='3d', computed_zorder=False)

# Make data
u = np.linspace(0, 2 * np.pi, 100)
v = np.linspace(0, np.pi, 100)
x = np.outer(np.cos(u), np.sin(v))
y = np.outer(np.sin(u), np.sin(v))
z = np.outer(np.ones(np.size(u)), np.cos(v))

# Plot the surface
ax.plot_surface(x, y, z, zorder=-1, alpha=0.5, color="white")
# Set an equal aspect ratio
ax.set_aspect('equal')

ax.scatter(center[0, 0],
           center[0, 1],
           center[0, 2],
           alpha=0.8, label="encoded point", zorder=999)
ax.scatter(samples[:, 0],
           samples[:, 1],
           samples[:, 2],
           alpha=0.8, label="samples for reconstruction")

ax.legend(fontsize=12)
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_zlim(-1, 1)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close()

# %%
from math import pi, atan2, asin, sqrt
import numpy as np
